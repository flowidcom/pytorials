# %% [markdown]
# # TR808 - The Drum Machine
#
#
# ![Image of TR808](https://upload.wikimedia.org/wikipedia/commons/4/4c/Roland_TR-808_%28large%29.jpg)

# %% [markdown]
# Built between 1980 and 1983 in Japan by Ikutaro Kakehashi

# %% [markdown]
# Music that uses the TR808:
# * Kanye West - 808s & Heartbreak - 2008, most popular Love Lockdown
# * Hudson Mohowke - Chimes
# And many others:
# * Usher - Yeah
# * Phil Collins - Another day in paradise
# * Gosh - In Colour
# * Daft Punk - Doin'it Right
# * Tiga - Sunglasses at Night
# * Bassnectar - 808 Track

# %%
YouTubeVideo('KC7UaUD5rEA', width=1024, height=576)

# %% [markdown]
# Funy drum machines:

# %%
YouTubeVideo('KC7UaUD5rEA', width=1024, height=576)

# %%
YouTubeVideo('', width=1024, height=576)

# %% [markdown]
# Read more:
# * Amazon Prime documentary - 808
# * Wikipedia - 808
